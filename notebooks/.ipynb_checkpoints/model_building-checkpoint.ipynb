# %%
# import numpy
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import os
from pathlib import Path
# import linear_model and datasets from sklearn
from sklearn import linear_model, datasets

# %%
merge_data = pd.read_csv('merge_data.csv')
merge_data.head(5)
# Out:
#    review_count  rating  bike_station  free_bikes  empty_slots  latitude  \
# 0           6.0     5.0             0           7           39  41.96909
# 1           6.0     5.0             0           7           39  41.96909
# 2           6.0     5.0             0           7           39  41.96909
# 3           6.0     5.0             0           7           39  41.96909
# 4           6.0     5.0             0           7           39  41.96909
#
#    longitude  distance
# 0 -87.674237        64
# 1 -87.674237        42
# 2 -87.674237       172
# 3 -87.674237        50
# 4 -87.674237        47

# %%
merge_data.describe()
# Out:
#         review_count         rating   bike_station     free_bikes  \
# count  108040.000000  108040.000000  108040.000000  108040.000000
# mean      112.556831       4.243613     292.118937       6.043132
# std       297.096537       0.848937     169.374708       4.576836
# min         0.000000       0.000000       0.000000       0.000000
# 25%        11.000000       4.000000     146.000000       2.000000
# 50%        38.000000       4.500000     292.000000       5.000000
# 75%       116.000000       4.500000     435.250000       9.000000
# max      9792.000000       5.000000     600.000000      25.000000
#
#          empty_slots       latitude      longitude     distance
# count  108040.000000  108040.000000  108040.000000  108040.0000
# mean        9.433728      41.879777     -87.653774     116.6000
# std         7.862702       0.078254       0.040165      64.9221
# min         0.000000      41.648501     -87.774704      42.0000
# 25%         5.000000      41.834734     -87.677856      50.0000
# 50%         8.000000      41.886875     -87.652855     110.5000
# 75%        12.000000      41.931248     -87.629544     162.0000
# max        51.000000      42.064854     -87.528232     249.0000

# %%
y = merge_data['free_bikes']
indep = merge_data.drop('free_bikes', axis=1)
X = [sm.add_constant(indep[column]) for column in indep.columns] 
X
# Out:
# [        const  review_count
#  0         1.0           6.0
#  1         1.0           6.0
#  2         1.0           6.0
#  3         1.0           6.0
#  4         1.0           6.0
#  ...       ...           ...
#  108035    1.0          27.0
#  108036    1.0          27.0
#  108037    1.0          27.0
#  108038    1.0          27.0
#  108039    1.0          27.0
#
#  [108040 rows x 2 columns],
#          const  rating
#  0         1.0     5.0
#  1         1.0     5.0
#  2         1.0     5.0
#  3         1.0     5.0
#  4         1.0     5.0
#  ...       ...     ...
#  108035    1.0     4.5
#  108036    1.0     4.5
#  108037    1.0     4.5
#  108038    1.0     4.5
#  108039    1.0     4.5
#
#  [108040 rows x 2 columns],
#          const  bike_station
#  0         1.0             0
#  1         1.0             0
#  2         1.0             0
#  3         1.0             0
#  4         1.0             0
#  ...       ...           ...
#  108035    1.0           600
#  108036    1.0           600
#  108037    1.0           600
#  108038    1.0           600
#  108039    1.0           600
#
#  [108040 rows x 2 columns],
#          const  empty_slots
#  0         1.0           39
#  1         1.0           39
#  2         1.0           39
#  3         1.0           39
#  4         1.0           39
#  ...       ...          ...
#  108035    1.0            6
#  108036    1.0            6
#  108037    1.0            6
#  108038    1.0            6
#  108039    1.0            6
#
#  [108040 rows x 2 columns],
#          const   latitude
#  0         1.0  41.969090
#  1         1.0  41.969090
#  2         1.0  41.969090
#  3         1.0  41.969090
#  4         1.0  41.969090
#  ...       ...        ...
#  108035    1.0  41.935581
#  108036    1.0  41.935581
#  108037    1.0  41.935581
#  108038    1.0  41.935581
#  108039    1.0  41.935581
#
#  [108040 rows x 2 columns],
#          const  longitude
#  0         1.0 -87.674237
#  1         1.0 -87.674237
#  2         1.0 -87.674237
#  3         1.0 -87.674237
#  4         1.0 -87.674237
#  ...       ...        ...
#  108035    1.0 -87.644042
#  108036    1.0 -87.644042
#  108037    1.0 -87.644042
#  108038    1.0 -87.644042
#  108039    1.0 -87.644042
#
#  [108040 rows x 2 columns],
#          const  distance
#  0         1.0        64
#  1         1.0        42
#  2         1.0       172
#  3         1.0        50
#  4         1.0        47
#  ...       ...       ...
#  108035    1.0       159
#  108036    1.0       109
#  108037    1.0       249
#  108038    1.0       112
#  108039    1.0       162
#
#  [108040 rows x 2 columns]]

# %%
Models = [sm.OLS(y,x) for x in X] #list of models
Results = [model.fit() for model in Models] #list of results
Adj_Rsquared = [results.rsquared_adj for results in Results] #list of rsquared
Pval = [results.pvalues for results in Results] #list of p-values
Params = [results.params for results in Results] #list of params

# %%
for i in range(len(Adj_Rsquared)):
     print(f'adj_R2: {Adj_Rsquared[i]:.3f}, P-values: {*Pval[i],}, column: {indep.columns[i]}')
# Out:
# adj_R2: 0.000, P-values: (0.0, 0.0005452682179099855), column: review_count
# adj_R2: 0.004, P-values: (0.0, 3.853907691545418e-96), column: rating
# adj_R2: 0.002, P-values: (0.0, 1.9480893692146179e-50), column: bike_station
# adj_R2: 0.310, P-values: (0.0, 0.0), column: empty_slots
# adj_R2: 0.006, P-values: (1.0250750530468502e-137, 1.172156385090497e-146), column: latitude
# adj_R2: 0.000, P-values: (0.054348568283230016, 0.08449435348667043), column: longitude
# adj_R2: -0.000, P-values: (0.0, 0.9999999999981914), column: distance

# %%
#run full model
y = merge_data['free_bikes']
X = merge_data.drop('free_bikes', axis=1)
X = sm.add_constant(X) #adds a column of 1's so the model will contain an intercept

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             free_bikes   R-squared:                       0.365
# Model:                            OLS   Adj. R-squared:                  0.365
# Method:                 Least Squares   F-statistic:                     8884.
# Date:                Sat, 03 Jun 2023   Prob (F-statistic):               0.00
# Time:                        19:46:37   Log-Likelihood:            -2.9307e+05
# No. Observations:              108040   AIC:                         5.862e+05
# Df Residuals:                  108032   BIC:                         5.862e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1677.5734     26.374     63.608      0.000    1625.882    1729.265
# review_count     0.0001   3.76e-05      3.104      0.002     4.3e-05       0.000
# rating           0.5329      0.015     35.110      0.000       0.503       0.563
# bike_station     0.0010    6.7e-05     15.069      0.000       0.001       0.001
# empty_slots     -0.3563      0.001   -244.280      0.000      -0.359      -0.353
# latitude        11.4736      0.198     57.862      0.000      11.085      11.862
# longitude       24.5426      0.344     71.376      0.000      23.869      25.217
# distance     -6.657e-16      0.000   -3.9e-12      1.000      -0.000       0.000
# ==============================================================================
# Omnibus:                    12988.572   Durbin-Watson:                   0.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21005.599
# Skew:                           0.848   Prob(JB):                         0.00
# Kurtosis:                       4.338   Cond. No.                     9.36e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.36e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
