# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect('merge_data.db')
c = conn.cursor()

# %%
# Run create table sql query
c.execute("create table if not exists merge_data" +
             " (review_count float, rating float,bike_station integer,free_bikes integer,empty_slots integer , longitude integer,latitude integer)")

# %%
# Load CSV data into Pandas DataFrame
merge = pd.read_csv('merge_data.csv')

# %%
# Write the data to a sqlite db table
merge.to_sql('merge_data', conn, if_exists='replace', index=False)

# %%
# Write the data to a sqlite db table
merge.to_sql('merge_data', conn, if_exists='replace', index=False)

# %%
# Run select sql query
c.execute('select * from merge_data')

# %%
records = c.fetchall()

# %%
# Display result 
for row in records:
    # show row
    print(row)
# Out:
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 64)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 42)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 172)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 50)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 47)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 159)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 109)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 249)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 112)
# (6.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 162)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 64)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 42)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 172)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 50)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 47)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 159)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 109)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 249)
# (34.0, 5.0, 0, 7, 39, 41.96909, -87.674237, 112)
# ...

# %%
# Close connection to SQLite database
c.close()
